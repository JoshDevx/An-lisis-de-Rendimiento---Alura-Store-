# %% [markdown]
# # 📊 Análisis de Ventas por Tienda - Alura Challenge LATAM

# %% [markdown]
# ## 📝 Informe Final: Recomendación de Tienda para el Sr. Juan
#
# ### 📌 Introducción
#
# El presente análisis tiene como objetivo identificar la tienda más adecuada para que el Sr. Juan venda sus productos, considerando una evaluación integral del rendimiento de cuatro tiendas virtuales. A través de herramientas de análisis de datos y visualización con Python, se examinaron múltiples factores claves, tales como: ingresos totales por tienda, categorías más vendidas, calificaciones promedio de los clientes, productos con mayor y menor demanda, y el costo de envío promedio por tienda. Con base en estos indicadores, se recomienda de forma justificada cuál de las tiendas presenta las mejores condiciones para una nueva incorporación comercial.
#
# ---
#
# ### 📊 Desarrollo del Análisis
#
# #### 1. **Ingresos Totales por Tienda**
# La tienda con mayores ventas fue:
#
# - 🥇 **Tienda 1**: 1,150,880,400
# - Tienda 2: 1,116,343,500
# - Tienda 3: 1,098,019,600
# - Tienda 4: 1,038,375,700
#
# **Tienda 1** se destaca como la de mayor facturación, lo cual indica un alto volumen de ventas y una sólida base de clientes.
#
# #### 2. **Categorías de Productos Más Vendidas**
# A nivel general, las categorías más rentables fueron:
#
# - Electrónicos (1,660 millones)
# - Electrodomésticos (1,324 millones)
# - Muebles (757 millones)
#
# Esto sugiere que los productos tecnológicos y del hogar dominan el mercado, mientras que categorías como Libros o Artículos para el hogar generan ingresos menores.
#
# #### 3. **Calificaciones Promedio por Tienda**
# Las calificaciones promedio de los clientes fueron:
#
# - 🥇 **Tienda 4**: 3.66
# - Tienda 3: 3.55
# - Tienda 1: 3.54
# - Tienda 2: 3.49
#
# **Tienda 4** se posiciona como la mejor evaluada por los clientes, lo cual puede reflejar una mejor experiencia de compra o atención al cliente.
#
# #### 4. **Productos Más y Menos Vendidos**
# Entre los productos más vendidos están:
#
# - Sillas de oficina
# - Cama King
# - Microondas
#
# Y los menos vendidos incluyen:
#
# - Juegos de ajedrez
# - Cajas de herramientas
# - Mochilas
#
# Este análisis es importante para alinear el inventario del Sr. Juan con la demanda del mercado de cada tienda.
#
# #### 5. **Costo de Envío Promedio**
# - 🥇 **Tienda 4** tiene el menor costo de envío promedio.
# - Tienda 2 y Tienda 1 presentan los mayores costos.
#
# Un menor costo de envío puede traducirse en mayor competitividad en precios finales al cliente, lo cual podría impactar positivamente las ventas.
#
# ---
#
# ### ✅ Conclusión y Recomendación
#
# Tras analizar en conjunto todos los factores, se concluye que:
#
# ### 🏆 **La mejor tienda para que el Sr. Juan venda sus productos es la _Tienda 1_.**
#
# **Justificación:**
#
# - Tiene el mayor volumen de ventas totales, lo que refleja una base de clientes activa y sólida.
# - Aunque su calificación no es la más alta, se mantiene competitiva y aceptable (3.54).
# - La tienda cuenta con alta demanda en categorías de alto valor como Electrónicos y Electrodomésticos, lo que puede ser favorable dependiendo del tipo de producto que desea vender el Sr. Juan.
# - Su variedad de productos más vendidos muestra rotación constante, y eso puede significar más oportunidades para posicionar nuevos productos.
#
# No obstante, si el Sr. Juan prioriza la **satisfacción del cliente y menor costo de envío**, entonces **Tienda 4** podría ser una segunda opción a considerar. Sin embargo, su volumen de ventas es menor, lo que representa un posible riesgo en términos de exposición.
#
# ---
#
# **👉 Recomendación final:**
# **El Sr. Juan debería vender en _Tienda 1_, priorizando el alto flujo de ventas y exposición del mercado, siempre que su producto esté alineado con las categorías de alta demanda.**
